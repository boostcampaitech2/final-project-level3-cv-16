# %%
from PIL import Image
import numpy as np
import requests
import json
import cv2
from easyocr import Reader
import matplotlib.pyplot as plt
import warnings 
from sklearn.cluster import DBSCAN
import pandas as pd
import os
from utils import predict, pre_predict
warnings.filterwarnings('ignore')

# %%
reader = Reader(['en', 'fr', 'is'], recognizer = 'Transformer')

# %%
image_path = "/opt/ml/"+"PieChartOcr/data/piedata/pie/images/test2019/f449d055d0020a85e6991e21e4b8e2df_d3d3LnphcG9wYW4uZ29iLm14CTIwMS4xMzAuMjAzLjE0MA==-0-0.png"
#image_path = "/opt/ml/"+"PieChartOcr/data/piedata/pie/images/test2019/f44b2c2c3d23a3aef554b3b2a3a681da_ZG9jZW50aS5sdWlzcy5pdAkxOTMuMjA0LjE1Ny4xMDU=.xls-0-0.png"

img = Image.open(image_path).convert("RGB")
img = np.array(img)

# %%
plt.figure(figsize=(14,16))
imgplot = plt.imshow(img)

# %%
pre_predict(reader, img, debug=False)
# Out:
# PORCENTAJE DE ASISTENCIA DEL CONSEJO CIUDADANO DE
# TRANSPARENCIA
# ZOILA GUIIÉ?REZ AVELARILAURA
# GABRIELA CARDENAS ECDRIGUEZ
# MARCO ANTONIO CERVERA
# DELGADILLO
# FRANCISO JAVIER JASSO MÉNDEZ
# JACQUELINE MONSERRAT DÍAZ
# RAMÍREZ
# CÉSAF CMAR MORA PÉREZ
# SEFGIO BERNARDINO BERNAL
# OSORNIO
# SEFGIO ISMAEL GONZÁLEZ LÓPEZ
#                                  0
# ZOILA GUIIÉ?REZ AVELARILAURA  16.7
# MARCO ANTONIO CERVERA         16.7
# FRANCISO JAVIER JASSO MÉNDEZ  16.6
# JACQUELINE MONSERRAT DÍAZ     11.1
# CÉSAF CMAR MORA PÉREZ          5.6
# SEFGIO BERNARDINO BERNAL      16.7
# SEFGIO ISMAEL GONZÁLEZ LÓPEZ  16.7

# %%
predict(reader, img, debug=False)
# Out:
# PORCENTAJE DE ASISTENCIA DEL CONSEJO CIUDADANO DE TRANSPARENCIA
# ZOILA GUIIÉ?REZ AVELARILAURA GABRIELA CARDENAS ECDRIGUEZ
# MARCO ANTONIO CERVERA DELGADILLO
# FRANCISO JAVIER JASSO MÉNDEZ
# JACQUELINE MONSERRAT DÍAZ RAMÍREZ
# CÉSAF CMAR MORA PÉREZ
# SEFGIO BERNARDINO BERNAL OSORNIO
# SEFGIO ISMAEL GONZÁLEZ LÓPEZ
#                                                        0
# ZOILA GUIIÉ?REZ AVELARILAURA GABRIELA CARDENAS ...  16.7
# MARCO ANTONIO CERVERA DELGADILLO                    16.7
# FRANCISO JAVIER JASSO MÉNDEZ                        16.6
# JACQUELINE MONSERRAT DÍAZ RAMÍREZ                   11.1
# CÉSAF CMAR MORA PÉREZ                                5.6
# SEFGIO BERNARDINO BERNAL OSORNIO                    16.7
# SEFGIO ISMAEL GONZÁLEZ LÓPEZ                        16.7

# %%
public_path = '/opt/ml/final-project-level3-cv-16/dev/workspace/Seungwoo/public_data'

# %%
os.chdir(public_path)

# %%
files = os.listdir(public_path)

# %%
files
# Out:
# ['10.png',
#  '1.png',
#  '8.jpeg',
#  '2.png',
#  '6.png',
#  '7.png',
#  '9.png',
#  '5.png',
#  '3.png',
#  '4.jpeg']

# %%
file = files[0]
img = Image.open(public_path+'/'+file).convert("RGB")
img = np.array(img)
plt.figure(figsize=(14,16))
imgplot = plt.imshow(img)

# %%
print('Pre_predict')
pre_predict(reader, img, debug=False)
# Out:
# Pre_predict
# Boston Celtics
# Los Angeles Lakers
# number:  22.979
# number:  22.97%
# Golden State Warriors
# number:  8.11%
# number:  8.119
# number:  31.079
# Chicago Bulls
# number:  6.769
# San
# Antonio Spurs
# Other Teams
#                           0
# Los Angeles Lakers     23.1
# Other Teams            31.0
# Antonio Spurs           6.8
# Chicago Bulls           8.1
# Golden State Warriors   8.2
# Boston Celtics         22.9

# %%
print('Now_predict')
predict(reader, img, debug=False)
# Out:
# Now_predict
# Boston Celtics
# Los Angeles Lakers
# number:  22.979
# number:  22.97%
# Golden State Warriors
# number:  8.11%
# number:  8.119
# number:  31.079
# Chicago Bulls
# number:  6.769
# San Antonio Spurs
# Other Teams
#                           0
# Los Angeles Lakers     23.1
# Other Teams            31.0
# San Antonio Spurs       6.8
# Chicago Bulls           8.1
# Golden State Warriors   8.2
# Boston Celtics         22.9

# %%
file = files[1]
img = Image.open(public_path+'/'+file).convert("RGB")
img = np.array(img)
plt.figure(figsize=(14,16))
imgplot = plt.imshow(img)

# %%
print('Pre_predict')
pre_predict(reader, img, debug=False)
# Out:
# Pre_predict
# number:  7 37
# number:  6.07%
# number:  23.46%
# number:  5.92%
# Single
# Married
# Separated
# Divorced
# Widowed
# No response
# number:  55.88%
#                 0
# Single       23.5
# Single       55.8
# Separated     6.0
# Divorced      6.1
# Widowed       7.4
# No response   1.3

# %%
print('Now_predict')
predict(reader, img, debug=False)
# Out:
# Now_predict
# number:  29
# number:  7 37
# number:  6.07%
# number:  23.46%
# number:  5.92%
# Single
# Married
# Separated
# Divorced
# Widowed
# No response
# number:  55.88%
#                 0
# Single       23.5
# Single       55.8
# Separated     6.0
# Divorced      6.1
# Widowed       7.4
# No response   1.3

# %%
image_path = "/opt/ml/"+"PieChartOcr/data/piedata/pie/images/test2019/f449d055d0020a85e6991e21e4b8e2df_d3d3LnphcG9wYW4uZ29iLm14CTIwMS4xMzAuMjAzLjE0MA==-0-0.png"
#image_path = "/opt/ml/"+"PieChartOcr/data/piedata/pie/images/test2019/f44b2c2c3d23a3aef554b3b2a3a681da_ZG9jZW50aS5sdWlzcy5pdAkxOTMuMjA0LjE1Ny4xMDU=.xls-0-0.png"

img = Image.open(image_path).convert("RGB")
img = np.array(img)

# %%
A = 12.3

# %%
set(str(A))
# Out:
# True

# %%
from PIL import ImageFont, ImageDraw, Image
import random


img = cv2.imread(image_path)
result = reader.readtext(img)
img = Image.fromarray(img) 
draw = ImageDraw.Draw(img) 
for i in result : 
    x = i[0][0][0] 
    y = i[0][0][1] 
    w = i[0][1][0] - i[0][0][0] 
    h = i[0][2][1] - i[0][1][1] 
    color = (8,8,8)
    draw.rectangle(((x, y), (x+w, y+h)), outline=tuple(color), width=2) 
    draw.text((int((x/3  + w) / 2) , y+15),str(i[1]), fill=tuple(color))
plt.figure(figsize=(14,16))
plt.imshow(img)
plt.show()

# %%
img = cv2.imread(image_path)
result = reader.readtext(img, text_threshold = 0)
img = Image.fromarray(img) 
draw = ImageDraw.Draw(img) 
for i in result : 
    x = i[0][0][0] 
    y = i[0][0][1] 
    w = i[0][1][0] - i[0][0][0] 
    h = i[0][2][1] - i[0][1][1] 
    color = (8,8,8)
    draw.rectangle(((x, y), (x+w, y+h)), outline=tuple(color), width=2) 
    draw.text((int((x/3  + w) / 2) , y+15),str(i[1]), fill=tuple(color))
plt.figure(figsize=(14,16))
plt.imshow(img)
plt.show()

# %%
img = cv2.imread(image_path)
result = reader.readtext(img, text_threshold = 0, paragraph = True)
img = Image.fromarray(img) 
draw = ImageDraw.Draw(img) 
for i in result : 
    x = i[0][0][0] 
    y = i[0][0][1] 
    w = i[0][1][0] - i[0][0][0] 
    h = i[0][2][1] - i[0][1][1] 
    color = (8,8,8)
    draw.rectangle(((x, y), (x+w, y+h)), outline=tuple(color), width=2) 
    draw.text((int((x/3  + w) / 2) , y+15),str(i[1]), fill=tuple(color))
plt.figure(figsize=(14,16))
plt.imshow(img)
plt.show()

# %%
img = cv2.imread(image_path)
result = reader.readtext(img, text_threshold = 0, paragraph = True, y_ths = 0)
img = Image.fromarray(img) 
draw = ImageDraw.Draw(img) 
for i in result : 
    x = i[0][0][0] 
    y = i[0][0][1] 
    w = i[0][1][0] - i[0][0][0] 
    h = i[0][2][1] - i[0][1][1] 
    color = (8,8,8)
    draw.rectangle(((x, y), (x+w, y+h)), outline=tuple(color), width=2) 
    draw.text((int((x/3  + w) / 2) , y+15),str(i[1]), fill=tuple(color))
plt.figure(figsize=(14,16))
plt.imshow(img)
plt.show()

# %%
img = cv2.imread(image_path)
result = reader.readtext(img, text_threshold = 0, paragraph = True, y_ths = 0.05)
img = Image.fromarray(img) 
draw = ImageDraw.Draw(img) 
for i in result : 
    x = i[0][0][0] 
    y = i[0][0][1] 
    w = i[0][1][0] - i[0][0][0] 
    h = i[0][2][1] - i[0][1][1] 
    color = (8,8,8)
    draw.rectangle(((x, y), (x+w, y+h)), outline=tuple(color), width=2) 
    draw.text((int((x/3  + w) / 2) , y+15),str(i[1]), fill=tuple(color))
plt.figure(figsize=(14,16))
plt.imshow(img)
plt.show()

# %%
img = cv2.imread(image_path)
result = reader.readtext(img, text_threshold = 0, paragraph = True, y_ths = 0, add_margin=0)
img = Image.fromarray(img) 
draw = ImageDraw.Draw(img) 
for i in result : 
    x = i[0][0][0] 
    y = i[0][0][1] 
    w = i[0][1][0] - i[0][0][0] 
    h = i[0][2][1] - i[0][1][1] 
    color = (8,8,8)
    draw.rectangle(((x, y), (x+w, y+h)), outline=tuple(color), width=2) 
    draw.text((int((x/3  + w) / 2) , y+15),str(i[1]), fill=tuple(color))
plt.figure(figsize=(14,16))
plt.imshow(img)
plt.show()

# %%
img = cv2.imread(image_path)
result = reader.readtext(img, text_threshold = 0, paragraph = True, y_ths = 0, add_margin=0, decoder = 'beamsearch', beamWidth = 100)
img = Image.fromarray(img) 
draw = ImageDraw.Draw(img) 
for i in result : 
    x = i[0][0][0] 
    y = i[0][0][1] 
    w = i[0][1][0] - i[0][0][0] 
    h = i[0][2][1] - i[0][1][1] 
    color = (8,8,8)
    draw.rectangle(((x, y), (x+w, y+h)), outline=tuple(color), width=2) 
    draw.text((int((x/3  + w) / 2) , y+15),str(i[1]), fill=tuple(color))
plt.figure(figsize=(14,16))
plt.imshow(img)
plt.show()

# %%
# Out:
# 범례 유무 : True
# Legend Points
# [(212.0, 293.0), (267.0, 293.0), (164.0, 293.0), (164.0, 293.0)]
#
# OCR 결과
# [([[255, 13], [383, 13], [383, 29], [255, 29]], 'IMPIEGHI 2002/2001', 0.9967523016815782), ([[339, 121], [365, 121], [365, 135], [339, 135]], '2996', 0.29472067873998103), ([[247, 165], [273, 165], [273, 179], [247, 179]], '579', 0.47255129515965244), ([[337, 197], [359, 197], [359, 211], [337, 211]], '88', 0.2516984391447747), ([[159, 287], [259, 287], [259, 301], [159, 301]], 'DCASS4 DCREDITI', 0.2516908241329063), ([[263, 287], [459, 287], [459, 301], [263, 301]], 'DSCORTE DAUKL INVEST. FissiLordi', 0.10006469869849934)]
#                                      0
# DSCORTE DAUKL INVEST. FissiLordi   5.8
# DSCORTE DAUKL INVEST. FissiLordi   8.2
# DCASS4 DCREDITI                   57.6
# DCASS4 DCREDITI                   28.5

# %%
# TODO : 글자 합치기
# TODO : 180도 이상 처리 - 하은님 코드 참고
# TODO : 파이 못잡았을 때 예외처리 or 아예 처음부터 BFS
